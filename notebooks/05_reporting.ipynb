# %% [markdown]
# # Reporting
#
# Generate final analytics report.

# %%
import json
from pathlib import Path
import pandas as pd

# %%
# Load analytics report
report_path = Path('reports/outputs/analytics_report.json')
if report_path.exists():
    report = json.loads(report_path.read_text())
    print('Summary:')
    for k, v in report.get('summary', {}).items():
        print(f'  {k}: {v}')
else:
    print('Run: python scripts/generate_report.py')
